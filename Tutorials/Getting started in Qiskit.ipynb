# %%
#Basic imports
import numpy as np
from qiskit import *
# %matplotlib inline

# %%
#Initialize a quantum circuit of two qubits
circ = QuantumCircuit(2)

# %%
#Design the circuit. That circuit transform |10> to |01> and |01> to |10>
circ.cx(0,1)
circ.cx(1,0)
circ.cx(0,1)

# %%
#Draw the circuit using matplotlib
circ.draw()
# Out:
# <pre style="word-wrap: normal;white-space: pre;background: #fff0;line-height: 1.1;font-family: &quot;Courier New&quot;,Courier,monospace">             ┌───┐
# q_0: |0>──■──┤ X ├──■──
#         ┌─┴─┐└─┬─┘┌─┴─┐
# q_1: |0>┤ X ├──■──┤ X ├
#         └───┘     └───┘</pre>

# %%
#Steps to use the backend of statevector simulator
from qiskit import Aer
backend = Aer.get_backend('statevector_simulator')

# %%
#Runing the circuit in a job object
#A job object has two methods: status and result
job = execute(circ, backend)

# %%
result = job.result()

# %%
output = result.get_statevector(circ, decimals=5)
output
# Out:
# array([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j])

# %%
from qiskit.visualization import plot_state_city
plot_state_city(output)
